# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\Internship\FUTURE_DS_01\data\superstore.csv", encoding='latin1')

print(df.head())

print(df.columns)

print(df.info())

print(df.describe())

print(df.isnull().sum())

df.drop_duplicates(inplace=True)

print("Total Sales:", df['Sales'].sum())
print("Total Profit:", df['Profit'].sum())

top_products = df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(12,6))
top_products.plot(kind='bar')
plt.title("Top 10 Products by Sales")
plt.ylabel("Sales")
plt.savefig("C:/Users/HP/OneDrive/Desktop/Internship/FUTURE_DS_01/images/top_products.png")
plt.show()

region_sales = df.groupby('Region')['Sales'].sum()

plt.figure(figsize=(8,5))
region_sales.plot(kind='pie', autopct='%1.1f%%')
plt.title("Sales by Region")
plt.ylabel("")
plt.savefig("C:/Users/HP/OneDrive/Desktop/Internship/FUTURE_DS_01/images/region_sales.png")
plt.show()

category_profit = df.groupby('Category')['Profit'].sum()

plt.figure(figsize=(8,5))
category_profit.plot(kind='bar')
plt.title("Profit by Category")
plt.ylabel("Profit")
plt.savefig("C:/Users/HP/OneDrive/Desktop/Internship/FUTURE_DS_01/images/category_profit.png")
plt.show()

df['Order Date'] = pd.to_datetime(df['Order Date'])

monthly_sales = df.groupby(df['Order Date'].dt.month)['Sales'].sum()

plt.figure(figsize=(10,5))
monthly_sales.plot(marker='o')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.savefig("C:/Users/HP/OneDrive/Desktop/Internship/FUTURE_DS_01/images/monthly_sales.png")
plt.show()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # Final Business Insights
#
# 1. Technology products generated strong revenue.
#
# 2. Certain products contribute significantly to total sales.
#
# 3. Regional performance varies considerably.
#
# 4. Seasonal trends affect revenue generation.
#
# 5. Some categories require profitability improvement.

# %% [markdown]
# # Recommendations
#
# 1. Increase promotion for high-performing products.
#
# 2. Expand operations in profitable regions.
#
# 3. Improve pricing strategies.
#
# 4. Focus on underperforming categories.
